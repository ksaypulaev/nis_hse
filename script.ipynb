# %%
import pandas as pd

# %%
pd.read_csv('plavki.csv', delimiter=',')
# Out:
#            id  date smena     steel_type  gost     C   Si    Mn     S   P  \
# 0  2024-01-01   308  SM_1  ГОСТ 380-2005   0.1  0.12  0.3  0.04  0.03 NaN
# 1  2024-01-01   308  SM_2  ГОСТ 14637-89   0.1  0.04  0.3  0.09  0.03 NaN
# 2  2024-01-01   308  SM_5  ГОСТ 16523-97   0.3  0.12  0.6  0.04  0.03 NaN
#
#    ...    Ni     Cu   N  Ti  Nb  Sn   V   B  Mo  Ca
# 0  ...  0.25  0.005 NaN NaN NaN NaN NaN NaN NaN NaN
# 1  ...  0.25  0.005 NaN NaN NaN NaN NaN NaN NaN NaN
# 2  ...  0.25  0.005 NaN NaN NaN NaN NaN NaN NaN NaN
#
# [3 rows x 22 columns]
